# %%
# !git clone https://github.com/ngocbao220/vilier.git

# %%
# %cd /kaggle/working/vilier

# %%
# !apt-get update
# !apt-get install -y ffmpeg
# !python -m pip install -U pip
# !python -m pip install -qr requirements/pyannote-community.txt

# %%
HUGGINGFACE_TOKEN = input('HUGGINGFACE_TOKEN: ')
INPUT_PATH = input('INPUT_PATH: ')
OUTPUT_PATH = input('OUTPUT_PATH: ')
DIARIZATION_BACKEND = 'pyannote'
DIARIZATION_MODEL = 'pyannote/speaker-diarization-community-1'

# %%
# !HUGGINGFACE_TOKEN="$HUGGINGFACE_TOKEN" INPUT_PATH="$INPUT_PATH" OUTPUT_PATH="$OUTPUT_PATH" bash run.sh \
  --diarization-backend "$DIARIZATION_BACKEND" \
  --diarization-model "$DIARIZATION_MODEL"
